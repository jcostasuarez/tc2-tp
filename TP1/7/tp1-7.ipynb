# %% [markdown]
# # Ejercicio 7

# %% [markdown]
# ##### C)Simule la función transferencia normalizada (Python, Matlab, etc.) :

# %%
from sympy.abc import s
from sympy.physics.control.lti import TransferFunction
from sympy.physics.control.control_plots import pole_zero_plot, bode_plot

tf1 = TransferFunction((s**2 - s*1 + 1), s**2 + s + 1, s)
pole_zero_plot(tf1)
bode_plot(tf1)

# %%
from sympy.abc import s
from sympy.physics.control.lti import TransferFunction
from sympy.physics.control.control_plots import pole_zero_plot, bode_plot

tf1 = TransferFunction(s-1, s+1, s)
pole_zero_plot(tf1)
bode_plot(tf1)
