# %% [markdown]
# # Trabajo Semanal 4 1 Revisión
#
# Trabajo semanal 4 - Entrega 23/5
# Se pide diseñar un filtro pasabanda que cumpla con la siguiente plantilla:
#
# ω0=2π 22 kHz
# Q=5
# Aproximación Chebyshev con ripple de 0,5 dB
# También se sabe que la transferencia del filtro debe ser:
#
# T(fS1)=-16 dB para fS1=17 kHz
# T(fS2)=-24 dB para fS2=36 kHz
#
# Consignas de la actividad:
#
# - Obtener la plantilla de diseño pasabanda normalizada
# - Obtener la función transferencia normalizada del prototipo pasabajo que satisfaga el requerimiento del filtro pasabanda.
# - Obtener la transferencia pasabanda normalizada
# - Implementar mediante secciones pasivas separadas por seguidores de tensión activos.
# - Activar las redes pasivas mediante la red propuesta aquí debajo y comprobar mediante simulación el comportamiento deseado.

# %%
from IPython.display import IFrame
IFrame("./img/plantilla.png", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/plantilla.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./img/circuito.png", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/circuito.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Resolución:

# %%
from IPython.display import IFrame
IFrame("./pdf/Resolución-1.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./pdf/Resolución-1.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import numpy as np
import scipy.signal as sig
import splane as tc2
import matplotlib.pyplot as plt

# elijo un orden luego de iterar ...
nn = 3
rp = 0.5
q = 5
f0 = 22E3

w0 = 2*np.pi * f0
b = w0 /q

num, den = sig.cheby1(nn, rp, 1, btype='low', analog=True, output='ba')

print('\n\n')
print('------------------')
print('Particiono en SOSs')
print('------------------')

# particiono en 2 SOS's para la implementación
sos_pa = tc2.tf2sos_analog(num, den)

### la visualizamos de algunas formas, la tradicional
tc2.pretty_print_SOS(sos_pa)

tc2.pretty_print_lti(num, den)

tc2.analyze_sys(sos_pa)
# Out:
# ------------------
# Particiono en SOSs
# ------------------
# $\displaystyle   \frac{1.116 }{s + 0.6265 } . \frac{0.6412 }{s^2 + s \,\, 0.6265 + 1.142 }$
# $\displaystyle \frac{0.7157 }{s^3 + s^2 \,\, 1.253 + s \,\, 1.535 + 0.7157 }$

# %%
import numpy as np
import scipy.signal as sig
import splane as tc2
import matplotlib.pyplot as plt

num_bp, den_bp = sig.lp2bp(num, den, bw = 1/q)

print('\n\n')
print('------------------')
print('Particiono en SOSs')
print('------------------')

# particiono en 2 SOS's para la implementación
sos_pa = tc2.tf2sos_analog(num_bp, den_bp)

tc2.pretty_print_lti(num_bp, den_bp)

### la visualizamos de algunas formas, la tradicional
tc2.pretty_print_SOS(sos_pa)

tc2.analyze_sys(sos_pa)
# Out:
# ------------------
# Particiono en SOSs
# ------------------
# $\displaystyle \frac{s^3 \,\, 0.005726 }{s^6 + s^5 \,\, 0.2506 + s^4 \,\, 3.061 + s^3 \,\, 0.5069 + s^2 \,\, 3.061 + s \,\, 0.2506 +   1 }$
# $\displaystyle   \frac{s \,\, 0.6022 }{s^2 + s \,\, 0.1253 +   1 } . \frac{s \,\, 0.108 }{s^2 + s \,\, 0.06902 + 1.226 } . \frac{s \,\, 0.08804 }{s^2 + s \,\, 0.05627 + 0.8154 }$

# %%
import numpy as np
import scipy.signal as sig
import splane as tc2
import matplotlib.pyplot as plt

num_bp, den_bp = sig.lp2bp(num, den,wo =w0 , bw = w0/q)

print('\n\n')
print('------------------')
print('Particiono en SOSs')
print('------------------')

# particiono en 2 SOS's para la implementación
sos_pa = tc2.tf2sos_analog(num_bp, den_bp)

tc2.pretty_print_lti(num_bp, den_bp)

### la visualizamos de algunas formas, la tradicional
tc2.pretty_print_SOS(sos_pa)

tc2.analyze_sys(sos_pa)
# Out:
# ------------------
# Particiono en SOSs
# ------------------
# $\displaystyle \frac{s^3 \,\, 1.512e+13 }{s^6 + s^5 \,\, 3.464e+04 + s^4 \,\, 5.85e+10 + s^3 \,\, 1.339e+15 + s^2 \,\, 1.118e+21 + s \,\, 1.265e+25 + 6.976e+30 }$
# $\displaystyle   \frac{s \,\, 0.0004142 }{s^2 + s \,\, 1.732e+04 + 1.911e+10 } . \frac{s \,\, 1.558e+08 }{s^2 + s \,\, 7779 + 1.558e+10 } . \frac{s \,\, 2.343e+08 }{s^2 + s \,\, 9540 + 2.343e+10 }$

# %% [markdown]
# # Circuitos:

# %%
from IPython.display import IFrame
IFrame("./pdf/Resolución-Circuitos.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./pdf/Resolución-Circuitos.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./img/pasive.png", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/pasive.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./img/pasivesimulationripple.jpg", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/pasivesimulationripple.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./img/pasivesimulationstop.jpg", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/pasivesimulationstop.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./img/circuitoactivo.jpg", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/circuitoactivo.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./img/activesimulationripple.jpg", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/activesimulationripple.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./img/activesimulationstop.jpg", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/activesimulationstop.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
