# %% [markdown]
# # Tarea semanal 5 | Juan Costa Suárez

# %%
from IPython.display import IFrame
IFrame("./pdf/ResoluciónTS5.1.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./pdf/ResoluciónTS5.1.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Simulaciones:

# %% [markdown]
# # 1)

# %%
from IPython.display import IFrame
IFrame("./img/circuitos.jpg", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/circuitos.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./img/1fase.jpg", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/1fase.jpg"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 2)

# %%
from sympy import simplify
from sympy.physics.control.lti import TransferFunction
from sympy.physics.control.control_plots import pole_zero_plot, bode_plot
from sympy import symbols
import matplotlib.pyplot as plt


#Acá tenes que declarar las variables
s = symbols('s')

K = 0.2512
expr1 = K*(s**2 + 1/K) / (s ** 2 + s * 1.414 + 1)

display(simplify(expr1))

tf1 = TransferFunction.from_rational_expression(expr1,var =s)

bode_plot(tf1,initial_exp=-1, final_exp=1.3)

pole_zero_plot(tf1)
# Out:
# (0.2512*s**2 + 1.0)/(s**2 + 1.414*s + 1)

# %%
expr1 = (s**2 + s * 0.707 + 1) / (s ** 2 + s * 1.414 + 1)

display(simplify(expr1))

tf1 = TransferFunction.from_rational_expression(expr1,var =s)

bode_plot(tf1, initial_exp=-1, final_exp=1)

pole_zero_plot(tf1)
# Out:
# (s**2 + 0.707*s + 1)/(s**2 + 1.414*s + 1)

# %%
import math

expr1 = (s**2 - s * 0.5 * 1.414 + 0.5**2) / (s ** 2 + s * 0.5 * 1.414 + 0.5**2)

display(simplify(expr1))

tf1 = TransferFunction.from_rational_expression(expr1,var =s)

bode_plot(tf1, initial_exp=-2, final_exp=2)

pole_zero_plot(tf1)
# Out:
# (s**2 - 0.707*s + 0.25)/(s**2 + 0.707*s + 0.25)

# %%
expr1 = 1/9*(s**2 + 9) / (s ** 2 + s * 1.414 + 1)

display(simplify(expr1))

tf1 = TransferFunction.from_rational_expression(expr1,var =s)

bode_plot(tf1, initial_exp=-2, final_exp=2)

pole_zero_plot(tf1)
# Out:
# (0.111111111111111*s**2 + 1.0)/(s**2 + 1.414*s + 1)

# %%
from IPython.display import IFrame
IFrame("./img/2circuitos.png", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/2circuitos.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./img/2.png", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/2.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 3)

# %%
#Acá tenes que declarar las variables
s = symbols('s')

K = 0.2512
expr1 = 6*(s) / (s ** 2 + 6*s + 4)

display(simplify(expr1))

tf1 = TransferFunction.from_rational_expression(expr1,var =s)

bode_plot(tf1,initial_exp=-1, final_exp=1.3)

pole_zero_plot(tf1)
# Out:
# 6*s/(s**2 + 6*s + 4)

# %%
from IPython.display import IFrame
IFrame("./img/3circuitos.png", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/3circuitos.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./img/3.png", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./img/3.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
